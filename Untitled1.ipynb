# %% [markdown]
# <a href="https://colab.research.google.com/github/gabriellaffagundes-ai/an-lise-de-dados/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
C = 55
F = C * 9/5 + 32
print(C, "graus Celsius corresponde a", F, "graus Fahrenheit")

C = 65
F = C * 9/5 + 32
print(C, "graus Celsius corresponde a", F, "graus Fahrenheit")
# Out:
# 55 graus Celsius corresponde a 131.0 graus Fahrenheit
# 65 graus Celsius corresponde a 149.0 graus Fahrenheit

# %%
# Delimitar qtd de casas decimais
"%.4f"
f se refere a float

# %%
a = int(input())
b = int(input())
c = int(input())

V = a*b*c

d = (a**2 + b**2 + c**2)**(1/2)

print("Volume:", "%.2f" %V, "Diagonal:", "%.2f" %d)
# Out:
# 19
# 10
# 10
# Volume: 1900.00 Diagonal: 23.69

# %%
import math
from math import pi

R = float(input()) # Valor do raio
A = pi * (R**2) # Área
print("%.4f" % A)
# Out:
# 10
# 314.1593

# %%
a = int(input())
b = int(input())
c = int(input())

V = a*b*c

d = (a**2 + b**2 + c**2)**(1/2)

print("Volume:", V, "Diagonal:", d)
# Out:
# 10
# 10
# 10
# Volume: 1000 Diagonal: 17.320508075688775

# %%
import math

raio = float(input())

print("%.4f" % (math.pi*raio**2))

# %%
media = float(input())

if media >= 8.5:
  print("conceito A")
  elif media >= 7.5
    if media>=7
    print("B")
    else
      if media<7
      print("C")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_3160/4073498044.py in <cell line: 0>()
# ----> 1 media = float(input())
#       2
#       3 if media >= 8.5:
#       4   print("conceito A")
#       5 elif media >= 7:
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %%
media = float(input())

if media >= 8.5:
  print("conceito A")
elif media >= 7.5:
  print("conceito B")
elif media >= 6.5:
  print("conceito C")
else:
  print("conceito D")
# Out:
# 10
# conceito A
